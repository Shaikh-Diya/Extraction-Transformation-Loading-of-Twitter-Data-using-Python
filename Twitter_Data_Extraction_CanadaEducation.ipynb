# %%
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import tweepy

ACCESS_TOKEN = '1188896442364186625-AJO20FRzCF554jT4oe98pkKbHXEgTI'
ACCESS_SECRET = 'fQrUlOI6szNrRMlvFl627ZTYfVafPMpJKKqd8CRqpDgA6'
CONSUMER_KEY = 'X2UhsEPyiy46M82nr2PdYmWdq'
CONSUMER_SECRET = 'B9aHLtxe3znUeotGR1hojKOOu4WEohADPqkN37eaHswXRmgCz6'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
for status in tweepy.Cursor(api.home_timeline).items(200):
	print(status._json)

# %%
import csv
class StreamListener(tweepy.StreamListener):
    
    def __init__(self):
        super(StreamListener, self).__init__()
        self.num_tweets=0

    def on_status(self, status):
        print(status.text)
        self.num_tweets+=1
        if(self.num_tweets<=3500):
            with open('Canada_Education.csv', 'a') as Canada_Education:
                writer = csv.writer(Canada_Education)
                
                writer.writerow([status.author.screen_name, status.created_at, status.text, status.user.location])
                
                return True
        else:
            return False
        
        
    #def on_data(self, data):
        #json_data = json.loads(data)
        #file.write(str(json_data))
         
    def on_error(self, status_code):
        if status_code == 420:
            return False

with open('Canada_Education.csv','w') as Canada_Education:
    writer = csv.writer(Canada_Education)
    writer.writerow(['Author', 'Date', 'Text', 'Location', 'Place' ])

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["Canada education"],languages=["en"])
Canada_Education.close()
# Out:
# @UNDPBiH
# I MOHAMED YUSSUF IS WELL EDUCATED PERSON AND I ALSO I HAVE DISCOVERED MY FOUR PRINCIPLE OF THE HUMAN BRAI… https://t.co/8xeTh0HuH5
# RT @TorontoStar: Her father was killed by the Taliban for championing his daughter to get an education. In 2012, Roya Shams escaped to Cana…
# RT @TarekFatah: Are you serious? The Muslim Brotherhood and Jamaat-e-Islami is drenched with engineers and physicians, not Muslims sufferin…
# RT @theworldindex: The top 10 countries for future skills education
#
# 1.🇫🇮 Finland
# 2.🇨🇭 Switzerland
# 3.🇳🇿 New Zealand
# 4.🇸🇪 Sweden
# 5.🇨🇦 Canada…
# RT @TarekFatah: Are you serious? The Muslim Brotherhood and Jamaat-e-Islami is drenched with engineers and physicians, not Muslims sufferin…
# RT @educationgadfly: How do we best help students who are several grade levels behind? It’s a vital question. But the very fact that it’s a…
# RT @hari2411: Dear @SenatorDurbin Do you read your own @chicagotribune ? Did you miss this ? https://t.co/8OJDxO7a9w
# International kids are…
# RT @jim_duffus: @MitchWheeler19 @TorontoStar This issue isn't about Western Canada's alienation it's about eastern  Canada's indifference t…
# RT @mmccdenier: Scheer's description of his past as an "insurance broker" also could expose him to legal danger, since the law criminalizes…
# 💯 not accurate. Ontario students are 2 or more years behind their peers. These are often autistic students excluded… https://t.co/lLxhF2WZZs
# RT @dbudlovsky: November, is Indigenous Education Month @TDSB. An opportunity to focus on treaties, the legacy of residential schools, as w…
# RT @TarekFatah: Are you serious? The Muslim Brotherhood and Jamaat-e-Islami is drenched with engineers and physicians, not Muslims sufferin…
# RT @TorontoStar: Her father was killed by the Taliban for championing his daughter to get an education. In 2012, Roya Shams escaped to Cana…
# RT @theworldindex: The top 10 countries for future skills education
#
# 1.🇫🇮 Finland
# 2.🇨🇭 Switzerland
# 3.🇳🇿 New Zealand
# 4.🇸🇪 Sweden
# 5.🇨🇦 Canada…
# RT @ed_inclusive: Australia is generations behind to other world education jurisdictions such as New Brunswick in Canada, failing not only…
# RT @TorontoStar: Her father was killed by the Taliban for championing his daughter to get an education. In 2012, Roya Shams escaped to Cana…
# RT @MaxBlumenthal: Sanders also called Hugo Chavez, who won far more hotly contested elections than he ever had &amp; who provided homes and fr…
# RT @mmccdenier: Scheer's description of his past as an "insurance broker" also could expose him to legal danger, since the law criminalizes…
# RT @Anniekidder: "Education is the key to reconciliation...if we educate  Indigenous children and non-Indigenous children about each other…
# RT @BJGrant: AMEN https://t.co/2lpVjFiZEf
# RT @MaxBlumenthal: Sanders also called Hugo Chavez, who won far more hotly contested elections than he ever had &amp; who provided homes and fr…
# RT @DashLalonde: Due to the policies of our Pedominster, our education system and courts are openly supporting the indoctrination of sexual…
# RT @theworldindex: The top 10 countries for future skills education
#
# 1.🇫🇮 Finland
# 2.🇨🇭 Switzerland
# 3.🇳🇿 New Zealand
# 4.🇸🇪 Sweden
# 5.🇨🇦 Canada…
